# %%
import pandas as pd

# Lista de artículos del 229 al 244 con su contenido
articulos_texto = {
    229: "Control Fiscal. El control fiscal de las entidades de que habla esta Ley, se hará por las respectivas Contralorías para las que tengan carácter oficial y por los controles estatutarios para las que tengan un carácter privado.",
    230: """Régimen Sancionatorio. La Superintendencia Nacional de Salud, previa solicitud de explicaciones, podrá imponer, en caso de violación a las normas contenidas en los artículos 161, 168, 178, 182, 183, 188, 204, 210, 225 y 227, por una sola vez, o en forma sucesiva, multas en cuantía hasta de 1.000 salarios mínimos legales mensuales vigentes a favor de la subcuenta de Solidaridad del Fondo de Solidaridad y Garantía.

El certificado de autorización que se les otorgue a las Empresas Promotoras de Salud podrá ser revocado o suspendido por la Superintendencia mediante providencia debidamente motivada, en los siguientes casos:
1. Petición de la Entidad Promotora de Salud.
2. Cuando la entidad deje de cumplir cualquiera de los requisitos establecidos para el otorgamiento de la autorización.
3. Cuando la entidad no haya iniciado su actividad en un plazo de 3 meses contados a partir de la fecha de otorgamiento del certificado de autorización.
4. Cuando la entidad ejecute prácticas de selección adversa.
5. Cuando se compruebe que no se prestan efectivamente los servicios previstos en el Plan de Salud Obligatorio.

Parágrafo 1. El Gobierno reglamentará los procedimientos de fusión, adquisición, liquidación, cesión de activos, pasivos y contratos, toma de posesión para administrar o liquidar y otros mecanismos aplicables a las entidades promotoras y prestadoras que permitan garantizar la adecuada prestación del servicio de salud a que hace referencia la presente Ley, protegiendo la confianza pública en el sistema.
Parágrafo 2. La Superintendencia Nacional de Salud ejercerá las funciones de inspección, control y vigilancia respecto de las Entidades Promotoras de Salud, cualquiera que sea su naturaleza jurídica.""",
    231: "Veedurías comunitarias. Sin perjuicio de los demás mecanismos de control y con el fin de garantizar cobertura, eficiencia y calidad de servicios, la prestación de los servicios mediante el régimen de subsidios en salud será objeto de control por parte de veedurías comunitarias elegidas popularmente, de acuerdo con la reglamentación que se expida para el efecto.",
    232: "Obligaciones de las Instituciones Prestadoras de Servicios de Salud. A las instituciones prestadoras del servicio de salud se les aplicarán las disposiciones contenidas en los artículos 225, 227 y 228 de qué trata la presente Ley, de acuerdo con la reglamentación que se expida para el efecto. El Ministerio de Salud definirá los casos excepcionales en donde no se exigirá la revisoría fiscal.",
    233: """De la Superintendencia Nacional de Salud. La Superintendencia Nacional de Salud es un organismo adscrito al Ministerio de Salud con personería jurídica, autonomía administrativa y patrimonio independiente.

Se adicionan funciones al Decreto 2165 de 1992:
1. Interrogar bajo juramento a personas útiles para el esclarecimiento de hechos.
2. Imponer multas sucesivas hasta de 1.000 salarios mínimos legales mensuales a las instituciones vigiladas que incumplan instrucciones.
3. Ordenar suspensión inmediata de prácticas ilegales.
4. Velar porque las entidades vigiladas suministren información clara y transparente a los usuarios.
5. Publicar estados financieros e indicadores del sector.
6. Fijar reglas generales de contabilidad para hospitales.
7. Practicar visitas de inspección a las entidades vigiladas.
8. Verificar provisiones en materia previsional y prestacional.
9. Inspeccionar y vigilar las EPS.

La Superintendencia también resolverá diferencias en materia de preexistencias en salud con apoyo de comités especializados.

Parágrafo 1. Se derogan algunos numerales del Decreto 2165 de 1992.
Parágrafo 2. Su procedimiento administrativo será el mismo que el de la Superintendencia Bancaria.
Parágrafo 3. Podrá contratar firmas de auditoría para el control del Fondo de Solidaridad y Garantía y EPS.""",
    234: """Régimen de Transición. El Sistema General de Seguridad Social en Salud tendrá un plazo máximo de un año, contado a partir de la vigencia de esta Ley, para iniciar su funcionamiento. 
Se crea la Comisión Técnica para la Transición, encargada de asesorar al Gobierno en la implementación del sistema. Estará compuesta por 5 expertos y reglamentada por el Gobierno.

Parágrafo 1. Las EPS creadas en desarrollo de esta Ley tendrán desde el inicio cobertura familiar para sus afiliados.""",
    235: """Del Instituto de Seguros Sociales. Durante la transición se mantienen las obligaciones de afiliación y cotización vigentes.
Quienes estén afiliados al ISS podrán trasladarse a otra EPS solo cuando la subcuenta de compensación del Fondo de Solidaridad y Garantía esté operando. 
La cobertura familiar en el ISS será progresiva en un plazo máximo de un año. 
Parágrafo. Los trabajadores del ISS mantendrán el carácter de empleados de la seguridad social (inexequible por sentencia C-579/96).""",
    236: """De las Cajas, Fondos y Entidades de Seguridad Social del Sector Público. Tendrán 2 años para transformarse en EPS, adaptarse al sistema o liquidarse. 
Los trabajadores recibirán el Plan Obligatorio de Salud y en un plazo de 4 años pagarán cotizaciones ajustadas. 
Si los beneficios superan el POS, se mantendrán como plan complementario. 
Las entidades que no requieran transformarse podrán seguir prestando servicios, ajustando gradualmente su régimen. 
En caso de liquidación, los empleadores deberán garantizar afiliación a otra EPS.

Parágrafos: 
1. Los nuevos servidores públicos se afiliarán al ISS o a cualquier EPS. 
2. Exención de impuestos en enajenaciones derivadas de reorganización. 
3. Posibilidad de liquidación por decisión de la mayoría de afiliados.""",
    237: "De la transición para el sector agropecuario. La obligación de empleadores y trabajadores de afiliarse al sistema de salud aplicará cuando exista oferta de servicios en la región.",
    238: """De la Financiación de los Hospitales Públicos. Las direcciones de salud deberán celebrar contratos de compraventa de servicios con hospitales. 
Durante 1995 y 1996 se tomarán como referencia presupuestal los valores asignados en 1994. 
Durante los tres primeros años, las instituciones que reciban recursos públicos recibirán al menos lo mismo que en el año fiscal anterior.""",
    239: """De las Entidades Territoriales. En un plazo máximo de dos años organizarán el régimen de subsidios en salud, de forma que los ingresos provengan de la venta de servicios. 
Deberán presentar al Ministerio de Salud los planes de transición para sustituir transferencias por subsidios a la demanda.""",
    240: """De las Cajas de Compensación Familiar. Podrán prestar servicios como EPS y tendrán el mismo plazo de transición del artículo 234. 
Durante este período deberán garantizar protección a sus beneficiarios y destinar recursos al régimen subsidiado conforme al artículo 217.

Parágrafo. Mientras los afiliados al ISS no puedan trasladarse, las familias podrán ser atendidas por cajas o EPS elegidas por el afiliado.""",
    241: "El Régimen de Tarifas. Un año después de la vigencia de la Ley se unificará el régimen de tarifas para las instituciones públicas prestadoras de servicios de salud, según reglamentación.",
    242: """Fondo Prestacional del Sector Salud. Cubre cesantías acumuladas y pasivo pensional hasta el 31 de diciembre de 1993. 
El costo adicional por retroactividad de cesantías será asumido por el Fondo del Pasivo Prestacional y entidades territoriales. 
Se prohíbe pactar retroactividad en cesantías a nuevos servidores. 
Las entidades deben seguir presupuestando y pagando cesantías y pensiones hasta el corte de cuentas.""",
    243: """Amnistía a las Instituciones Prestadoras de Salud. El ISS y el Fondo Nacional del Ahorro deberán afiliar a los servidores de salud una vez se defina el pago de la deuda por cesantías y pasivo pensional. 
Se condonarán multas y sanciones a entidades públicas que no hayan afiliado o pagado antes de diciembre de 1993, especialmente aquellas en causal de liquidación.""",
    244: """Sobre el Funcionamiento del Seguro Obligatorio de Accidentes de Tránsito (SOAT). 
- Aseguradoras destinarán 3% de primas a campañas de prevención vial. 
- Certificación de ocurrencia del accidente será expedida por el médico que atienda la urgencia. 
- Beneficiarios de indemnizaciones serán los definidos en el Código de Comercio, incluyendo compañeros permanentes. 
- Gobierno fijará tarifas para atención médica de víctimas de tránsito. 
- Aseguradoras que dilaten pagos serán sancionadas. 
- Se exige anticipo en caso de objeciones a reclamaciones. 
- Recursos del SOAT también cubrirán víctimas de catástrofes y actos terroristas. 
- Aseguradoras deberán transferir bimestralmente 20% de las primas al FONSAT."""
}

# %%
# Crear DataFrame
df_articulos = pd.DataFrame(list(articulos_texto.items()), columns=["articulo", "texto_del_articulo"])


# Reordenar columnas
df_articulos = df_articulos[["articulo", "texto_del_articulo"]]

# Guardar en CSV
output_path = "articulos_229_244.csv"
df_articulos.to_csv(output_path, index=False, encoding="utf-8-sig")
